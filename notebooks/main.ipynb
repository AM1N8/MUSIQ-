# %%
MUSIC_DATA_PATH = "../data/raw/songs.csv"
USER_DATA_PATH = "../data/raw/users.csv"

# %%
import pandas as pd
import numpy as np

# %%
music_df = pd.read_csv(MUSIC_DATA_PATH)
user_df = pd.read_csv(USER_DATA_PATH)

# %%
music_df
# Out:
#                                      track_id    duration  release_year  \
# 0      t_3c2c29b5-c738-42c0-83e1-ee0e88ac834d  182.293335          1969
# 1      t_f48322ca-044e-4069-a797-4fedbbbbb522  237.000000          1980
# 2      t_5487f622-5641-43da-b263-d8954845d163  365.239990          1971
# 3      t_7345e2b8-5f72-440f-a0fc-81bf7e8996f2  295.000000          1976
# 4      t_faa63385-9547-4b18-b942-529285cc2ab6  249.293335          1975
# ...                                       ...         ...           ...
# 20773  t_586d5f58-a2db-4d88-a64b-e6d2a4a98d6c  134.500000          2018
# 20774  t_4fa7d39b-5085-4369-9759-401250c93ef1  170.538498          2018
# 20775  t_e081f171-8761-484f-a1f9-233b6690e05c   60.000000          2018
# 20776  t_60e12e04-5a31-40db-9db4-1b43efe6c0eb  190.026672          2018
# 20777  t_395c0c84-fdb3-4b2a-a223-5225770205c8  236.546677          2018
#
#        us_popularity_estimate  acousticness  beat_strength  bounciness  \
# ...

# %%
user_df
# Out:
#                                    session_id  session_position  \
# 0      0_00006f66-33e5-4de7-a324-2d18e439fc1e                 1
# 1      0_00006f66-33e5-4de7-a324-2d18e439fc1e                 2
# 2      0_00006f66-33e5-4de7-a324-2d18e439fc1e                 3
# 3      0_00006f66-33e5-4de7-a324-2d18e439fc1e                 4
# 4      0_00006f66-33e5-4de7-a324-2d18e439fc1e                 5
# ...                                       ...               ...
# 99995  0_08b98bb8-29ce-44d9-8839-914e31a11044                 7
# 99996  0_08b98bb8-29ce-44d9-8839-914e31a11044                 8
# 99997  0_08b98bb8-29ce-44d9-8839-914e31a11044                 9
# 99998  0_08b98bb8-29ce-44d9-8839-914e31a11044                10
# 99999  0_08b98bb8-29ce-44d9-8839-914e31a11044                11
#
#        session_length                          track_id_clean  skip_1  skip_2  \
# 0                  20  t_0479f24c-27d2-46d6-a00c-7ec928f2b539   False   False
# ...
